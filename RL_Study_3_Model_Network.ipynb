# %%
import numpy as np
import pickle
import tensorflow as tf
# %matplotlib inline
import matplotlib.pyplot as plt
import math

# from modelAny import *

from tensorflow.python.framework import dtypes
from tensorflow.python.framework import ops
from tensorflow.python.ops import array_ops
from tensorflow.python.ops import control_flow_ops
from tensorflow.python.ops import embedding_ops
from tensorflow.python.ops import math_ops
from tensorflow.python.ops import nn_ops
from tensorflow.python.ops import rnn
from tensorflow.python.ops import rnn_cell
from tensorflow.python.ops import variable_scope


import sys
if sys.version_info.major > 2:
    xrange = range
del sys


import gym
env = gym.make('CartPole-v0')
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.

# %%
# hyperparameters
H = 8 # number of hidden layer neurons
learning_rate = 1e-2
gamma = 0.99 # discount factor for reward
decay_rate = 0.99 # decay factor for RMSProp leaky sum of grad^2
resume = False # resume from previous checkpoint?

model_bs = 3 # Batch size when learning from model
real_bs = 3 # Batch size when learning from real environment

# model initialization
D = 4 # input dimensionality

# %%
tf.reset_default_graph()
observations = tf.placeholder(tf.float32, [None,4] , name="input_x")
W1 = tf.get_variable("W1", shape=[4, H],
           initializer=tf.contrib.layers.xavier_initializer())
layer1 = tf.nn.relu(tf.matmul(observations,W1))
W2 = tf.get_variable("W2", shape=[H, 1],
           initializer=tf.contrib.layers.xavier_initializer())
score = tf.matmul(layer1,W2)
probability = tf.nn.sigmoid(score)

tvars = tf.trainable_variables()
input_y = tf.placeholder(tf.float32,[None,1], name="input_y")
advantages = tf.placeholder(tf.float32,name="reward_signal")
adam = tf.train.AdamOptimizer(learning_rate=learning_rate)
W1Grad = tf.placeholder(tf.float32,name="batch_grad1")
W2Grad = tf.placeholder(tf.float32,name="batch_grad2")
batchGrad = [W1Grad,W2Grad]
loglik = tf.log(input_y*(input_y - probability) + (1 - input_y)*(input_y + probability))
loss = -tf.reduce_mean(loglik * advantages) 
newGrads = tf.gradients(loss,tvars)
updateGrads = adam.apply_gradients(zip(batchGrad,tvars))

# %%
mH = 256 # model layer size

input_data = tf.placeholder(tf.float32, [None, 5])
with tf.variable_scope('rnnlm'):
    softmax_w = tf.get_variable("softmax_w", [mH, 50])
    softmax_b = tf.get_variable("softmax_b", [50])

previous_state = tf.placeholder(tf.float32, [None,5] , name="previous_state")
W1M = tf.get_variable("W1M", shape=[5, mH],
           initializer=tf.contrib.layers.xavier_initializer())
B1M = tf.Variable(tf.zeros([mH]),name="B1M")
layer1M = tf.nn.relu(tf.matmul(previous_state,W1M) + B1M)
W2M = tf.get_variable("W2M", shape=[mH, mH],
           initializer=tf.contrib.layers.xavier_initializer())
B2M = tf.Variable(tf.zeros([mH]),name="B2M")
layer2M = tf.nn.relu(tf.matmul(layer1M,W2M) + B2M)
wO = tf.get_variable("wO", shape=[mH, 4],
           initializer=tf.contrib.layers.xavier_initializer())
wR = tf.get_variable("wR", shape=[mH, 1],
           initializer=tf.contrib.layers.xavier_initializer())
wD = tf.get_variable("wD", shape=[mH, 1],
           initializer=tf.contrib.layers.xavier_initializer())

bO = tf.Variable(tf.zeros([4]),name="bO")
bR = tf.Variable(tf.zeros([1]),name="bR")
bD = tf.Variable(tf.ones([1]),name="bD")


predicted_observation = tf.matmul(layer2M,wO,name="predicted_observation") + bO
predicted_reward = tf.matmul(layer2M,wR,name="predicted_reward") + bR
predicted_done = tf.sigmoid(tf.matmul(layer2M,wD,name="predicted_done") + bD)

true_observation = tf.placeholder(tf.float32,[None,4],name="true_observation")
true_reward = tf.placeholder(tf.float32,[None,1],name="true_reward")
true_done = tf.placeholder(tf.float32,[None,1],name="true_done")


predicted_state = tf.concat([predicted_observation,predicted_reward,predicted_done],1)

observation_loss = tf.square(true_observation - predicted_observation)

reward_loss = tf.square(true_reward - predicted_reward)

done_loss = tf.multiply(predicted_done, true_done) + tf.multiply(1-predicted_done, 1-true_done)
done_loss = -tf.log(done_loss)

model_loss = tf.reduce_mean(observation_loss + done_loss + reward_loss)

modelAdam = tf.train.AdamOptimizer(learning_rate=learning_rate)
updateModel = modelAdam.minimize(model_loss)

# %%
def resetGradBuffer(gradBuffer):
    for ix,grad in enumerate(gradBuffer):
        gradBuffer[ix] = grad * 0
    return gradBuffer
        
def discount_rewards(r):
    """ take 1D float array of rewards and compute discounted reward """
    discounted_r = np.zeros_like(r)
    running_add = 0
    for t in reversed(xrange(0, r.size)):
        running_add = running_add * gamma + r[t]
        discounted_r[t] = running_add
    return discounted_r


# This function uses our model to produce a new state when given a previous state and action
def stepModel(sess, xs, action):
    toFeed = np.reshape(np.hstack([xs[-1][0],np.array(action)]),[1,5])
    myPredict = sess.run([predicted_state],feed_dict={previous_state: toFeed})
    reward = myPredict[0][:,4]
    observation = myPredict[0][:,0:4]
    observation[:,0] = np.clip(observation[:,0],-2.4,2.4)
    observation[:,2] = np.clip(observation[:,2],-0.4,0.4)
    doneP = np.clip(myPredict[0][:,5],0,1)
    if doneP > 0.1 or len(xs)>= 300:
        done = True
    else:
        done = False
    return observation, reward, done

# %%
xs,drs,ys,ds = [],[],[],[]
running_reward = None
reward_sum = 0
episode_number = 1
real_episodes = 1
init = tf.global_variables_initializer()
batch_size = real_bs

drawFromModel = False # When set to True, will use model for observations
trainTheModel = True # Whether to train the model
trainThePolicy = False # Whether to train the policy
switch_point = 1

# Launch the graph
with tf.Session() as sess:
    rendering = False
    sess.run(init)
    observation = env.reset()
    x = observation
    gradBuffer = sess.run(tvars)
    gradBuffer = resetGradBuffer(gradBuffer)
    
    while episode_number <= 5000:
        # Start displaying environment once performance is acceptably high.
        if (reward_sum/batch_size > 150 and drawFromModel == False) or rendering == True : 
            env.render()
            rendering = True
            
        x = np.reshape(observation,[1,4])

        tfprob = sess.run(probability,feed_dict={observations: x})
        action = 1 if np.random.uniform() < tfprob else 0

        # record various intermediates (needed later for backprop)
        xs.append(x) 
        y = 1 if action == 0 else 0 
        ys.append(y)
        
        # step the  model or real environment and get new measurements
        if drawFromModel == False:
            observation, reward, done, info = env.step(action)
        else:
            observation, reward, done = stepModel(sess,xs,action)
                
        reward_sum += reward
        
        ds.append(done*1)
        drs.append(reward) # record reward (has to be done after we call step() to get reward for previous action)

        if done: 
            
            if drawFromModel == False: 
                real_episodes += 1
            episode_number += 1

            # stack together all inputs, hidden states, action gradients, and rewards for this episode
            epx = np.vstack(xs)
            epy = np.vstack(ys)
            epr = np.vstack(drs)
            epd = np.vstack(ds)
            xs,drs,ys,ds = [],[],[],[] # reset array memory
            
            if trainTheModel == True:
                actions = np.array([np.abs(y-1) for y in epy][:-1])
                state_prevs = epx[:-1,:]
                state_prevs = np.hstack([state_prevs,actions])
                state_nexts = epx[1:,:]
                rewards = np.array(epr[1:,:])
                dones = np.array(epd[1:,:])
                state_nextsAll = np.hstack([state_nexts,rewards,dones])

                feed_dict={previous_state: state_prevs, true_observation: state_nexts,true_done:dones,true_reward:rewards}
                loss,pState,_ = sess.run([model_loss,predicted_state,updateModel],feed_dict)
            if trainThePolicy == True:
                discounted_epr = discount_rewards(epr).astype('float32')
                discounted_epr -= np.mean(discounted_epr)
                discounted_epr /= np.std(discounted_epr)
                tGrad = sess.run(newGrads,feed_dict={observations: epx, input_y: epy, advantages: discounted_epr})
                
                # If gradients becom too large, end training process
                if np.sum(tGrad[0] == tGrad[0]) == 0:
                    break
                for ix,grad in enumerate(tGrad):
                    gradBuffer[ix] += grad
                
            if switch_point + batch_size == episode_number: 
                switch_point = episode_number
                if trainThePolicy == True:
                    sess.run(updateGrads,feed_dict={W1Grad: gradBuffer[0],W2Grad:gradBuffer[1]})
                    gradBuffer = resetGradBuffer(gradBuffer)

                running_reward = reward_sum if running_reward is None else running_reward * 0.99 + reward_sum * 0.01
                if drawFromModel == False:
                    print('World Perf: Episode %f. Reward %f. action: %f. mean reward %f.' % (real_episodes,reward_sum/real_bs,action, running_reward/real_bs))
                    if reward_sum/batch_size > 200:
                        break
                reward_sum = 0

                # Once the model has been trained on 100 episodes, we start alternating between training the policy
                # from the model and training the model from the real environment.
                if episode_number > 100:
                    drawFromModel = not drawFromModel
                    trainTheModel = not trainTheModel
                    trainThePolicy = not trainThePolicy
            
            if drawFromModel == True:
                observation = np.random.uniform(-0.1,0.1,[4]) # Generate reasonable starting point
                batch_size = model_bs
            else:
                observation = env.reset()
                batch_size = real_bs
                
print(real_episodes)
# Out:
# World Perf: Episode 4.000000. Reward 46.666667. action: 0.000000. mean reward 46.666667.
# World Perf: Episode 7.000000. Reward 38.333333. action: 1.000000. mean reward 46.583333.
# World Perf: Episode 10.000000. Reward 24.000000. action: 0.000000. mean reward 46.357500.
# World Perf: Episode 13.000000. Reward 25.666667. action: 0.000000. mean reward 46.150592.
# World Perf: Episode 16.000000. Reward 29.666667. action: 1.000000. mean reward 45.985752.
# World Perf: Episode 19.000000. Reward 28.666667. action: 1.000000. mean reward 45.812562.
# World Perf: Episode 22.000000. Reward 22.000000. action: 1.000000. mean reward 45.574436.
# World Perf: Episode 25.000000. Reward 22.333333. action: 0.000000. mean reward 45.342025.
# World Perf: Episode 28.000000. Reward 24.000000. action: 1.000000. mean reward 45.128605.
# World Perf: Episode 31.000000. Reward 17.000000. action: 1.000000. mean reward 44.847319.
# World Perf: Episode 34.000000. Reward 27.333333. action: 0.000000. mean reward 44.672179.
# World Perf: Episode 37.000000. Reward 34.333333. action: 1.000000. mean reward 44.568790.
# World Perf: Episode 40.000000. Reward 21.000000. action: 1.000000. mean reward 44.333102.
# World Perf: Episode 43.000000. Reward 20.000000. action: 0.000000. mean reward 44.089771.
# World Perf: Episode 46.000000. Reward 30.666667. action: 1.000000. mean reward 43.955540.
# World Perf: Episode 49.000000. Reward 16.666667. action: 0.000000. mean reward 43.682652.
# World Perf: Episode 52.000000. Reward 32.333333. action: 1.000000. mean reward 43.569158.
# World Perf: Episode 55.000000. Reward 35.666667. action: 0.000000. mean reward 43.490134.
# World Perf: Episode 58.000000. Reward 26.666667. action: 0.000000. mean reward 43.321899.
# World Perf: Episode 61.000000. Reward 19.333333. action: 0.000000. mean reward 43.082013.
# World Perf: Episode 64.000000. Reward 24.666667. action: 1.000000. mean reward 42.897860.
# World Perf: Episode 67.000000. Reward 19.333333. action: 1.000000. mean reward 42.662214.
# World Perf: Episode 70.000000. Reward 29.000000. action: 0.000000. mean reward 42.525592.
# World Perf: Episode 73.000000. Reward 18.666667. action: 0.000000. mean reward 42.287003.
# World Perf: Episode 76.000000. Reward 18.000000. action: 1.000000. mean reward 42.044133.
# World Perf: Episode 79.000000. Reward 16.333333. action: 1.000000. mean reward 41.787025.
# World Perf: Episode 82.000000. Reward 38.333333. action: 1.000000. mean reward 41.752488.
# World Perf: Episode 85.000000. Reward 19.666667. action: 0.000000. mean reward 41.531630.
# World Perf: Episode 88.000000. Reward 26.666667. action: 0.000000. mean reward 41.382980.
# World Perf: Episode 91.000000. Reward 32.666667. action: 1.000000. mean reward 41.295817.
# World Perf: Episode 94.000000. Reward 17.000000. action: 0.000000. mean reward 41.052859.
# World Perf: Episode 97.000000. Reward 26.666667. action: 0.000000. mean reward 40.908997.
# World Perf: Episode 100.000000. Reward 22.333333. action: 1.000000. mean reward 40.723240.
# World Perf: Episode 103.000000. Reward 21.333333. action: 0.000000. mean reward 40.529341.
# World Perf: Episode 106.000000. Reward 27.333333. action: 1.000000. mean reward 40.104305.
# World Perf: Episode 109.000000. Reward 30.333333. action: 1.000000. mean reward 39.789536.
# World Perf: Episode 112.000000. Reward 23.000000. action: 1.000000. mean reward 39.562336.
# World Perf: Episode 115.000000. Reward 16.666667. action: 1.000000. mean reward 39.066788.
# World Perf: Episode 118.000000. Reward 16.333333. action: 0.000000. mean reward 38.532505.
# World Perf: Episode 121.000000. Reward 30.333333. action: 0.000000. mean reward 38.282433.
# World Perf: Episode 124.000000. Reward 68.000000. action: 0.000000. mean reward 38.775646.
# World Perf: Episode 127.000000. Reward 50.000000. action: 1.000000. mean reward 38.606331.
# World Perf: Episode 130.000000. Reward 31.333333. action: 1.000000. mean reward 38.205593.
# World Perf: Episode 133.000000. Reward 23.000000. action: 0.000000. mean reward 37.722309.
# World Perf: Episode 136.000000. Reward 25.000000. action: 1.000000. mean reward 37.263008.
# World Perf: Episode 139.000000. Reward 29.666667. action: 0.000000. mean reward 36.871593.
# World Perf: Episode 142.000000. Reward 87.000000. action: 0.000000. mean reward 37.066879.
# World Perf: Episode 145.000000. Reward 43.666667. action: 1.000000. mean reward 38.672680.
# World Perf: Episode 148.000000. Reward 25.666667. action: 0.000000. mean reward 38.285061.
# World Perf: Episode 151.000000. Reward 48.666667. action: 1.000000. mean reward 38.271355.
# World Perf: Episode 154.000000. Reward 25.333333. action: 0.000000. mean reward 37.922012.
# World Perf: Episode 157.000000. Reward 32.666667. action: 0.000000. mean reward 37.601650.
# World Perf: Episode 160.000000. Reward 45.666667. action: 0.000000. mean reward 37.353504.
# World Perf: Episode 163.000000. Reward 41.333333. action: 0.000000. mean reward 37.102245.
# World Perf: Episode 166.000000. Reward 28.000000. action: 0.000000. mean reward 36.753986.
# World Perf: Episode 169.000000. Reward 49.666667. action: 0.000000. mean reward 37.210529.
# World Perf: Episode 172.000000. Reward 47.666667. action: 1.000000. mean reward 39.881393.
# World Perf: Episode 175.000000. Reward 69.666667. action: 0.000000. mean reward 39.942101.
# World Perf: Episode 178.000000. Reward 28.000000. action: 1.000000. mean reward 39.554352.
# World Perf: Episode 181.000000. Reward 43.000000. action: 1.000000. mean reward 43.075851.
# World Perf: Episode 184.000000. Reward 44.000000. action: 0.000000. mean reward 46.535900.
# World Perf: Episode 187.000000. Reward 25.000000. action: 1.000000. mean reward 45.986404.
# World Perf: Episode 190.000000. Reward 53.333333. action: 0.000000. mean reward 48.610325.
# World Perf: Episode 193.000000. Reward 51.333333. action: 1.000000. mean reward 48.251331.
# World Perf: Episode 196.000000. Reward 32.333333. action: 1.000000. mean reward 47.704681.
# World Perf: Episode 199.000000. Reward 58.000000. action: 1.000000. mean reward 47.600811.
# World Perf: Episode 202.000000. Reward 39.666667. action: 1.000000. mean reward 50.557293.
# World Perf: Episode 205.000000. Reward 23.333333. action: 1.000000. mean reward 50.055820.
# World Perf: Episode 208.000000. Reward 53.666667. action: 1.000000. mean reward 49.712234.
# World Perf: Episode 211.000000. Reward 28.666667. action: 0.000000. mean reward 50.024586.
# World Perf: Episode 214.000000. Reward 40.000000. action: 1.000000. mean reward 52.605854.
# World Perf: Episode 217.000000. Reward 34.666667. action: 0.000000. mean reward 52.642742.
# World Perf: Episode 220.000000. Reward 34.666667. action: 1.000000. mean reward 52.268494.
# World Perf: Episode 223.000000. Reward 27.666667. action: 1.000000. mean reward 51.867435.
# World Perf: Episode 226.000000. Reward 22.333333. action: 0.000000. mean reward 51.239254.
# World Perf: Episode 229.000000. Reward 33.000000. action: 1.000000. mean reward 50.667934.
# World Perf: Episode 232.000000. Reward 34.000000. action: 0.000000. mean reward 50.402283.
# World Perf: Episode 235.000000. Reward 68.666667. action: 1.000000. mean reward 50.396313.
# World Perf: Episode 238.000000. Reward 43.333333. action: 1.000000. mean reward 50.517593.
# World Perf: Episode 241.000000. Reward 47.000000. action: 1.000000. mean reward 50.257290.
# World Perf: Episode 244.000000. Reward 36.000000. action: 1.000000. mean reward 51.429379.
# World Perf: Episode 247.000000. Reward 49.000000. action: 0.000000. mean reward 51.023098.
# World Perf: Episode 250.000000. Reward 34.666667. action: 1.000000. mean reward 50.687237.
# World Perf: Episode 253.000000. Reward 35.333333. action: 0.000000. mean reward 52.869411.
# World Perf: Episode 256.000000. Reward 18.000000. action: 1.000000. mean reward 52.143749.
# World Perf: Episode 259.000000. Reward 35.666667. action: 1.000000. mean reward 51.574352.
# World Perf: Episode 262.000000. Reward 54.666667. action: 0.000000. mean reward 51.407536.
# World Perf: Episode 265.000000. Reward 23.000000. action: 1.000000. mean reward 51.579098.
# World Perf: Episode 268.000000. Reward 39.333333. action: 1.000000. mean reward 51.731960.
# World Perf: Episode 271.000000. Reward 54.333333. action: 0.000000. mean reward 51.415127.
# World Perf: Episode 274.000000. Reward 64.666667. action: 1.000000. mean reward 54.280807.
# World Perf: Episode 277.000000. Reward 53.666667. action: 1.000000. mean reward 54.116901.
# World Perf: Episode 280.000000. Reward 41.000000. action: 0.000000. mean reward 53.533722.
# World Perf: Episode 283.000000. Reward 45.000000. action: 0.000000. mean reward 53.200008.
# World Perf: Episode 286.000000. Reward 33.666667. action: 0.000000. mean reward 52.550037.
# World Perf: Episode 289.000000. Reward 84.333333. action: 1.000000. mean reward 52.397076.
# World Perf: Episode 292.000000. Reward 78.666667. action: 1.000000. mean reward 52.721298.
# World Perf: Episode 295.000000. Reward 35.000000. action: 0.000000. mean reward 52.358044.
# World Perf: Episode 298.000000. Reward 19.666667. action: 0.000000. mean reward 51.548218.
# World Perf: Episode 301.000000. Reward 35.666667. action: 1.000000. mean reward 50.951084.
# World Perf: Episode 304.000000. Reward 51.666667. action: 1.000000. mean reward 54.010540.
# World Perf: Episode 307.000000. Reward 41.000000. action: 1.000000. mean reward 53.462345.
# World Perf: Episode 310.000000. Reward 54.333333. action: 0.000000. mean reward 54.267292.
# World Perf: Episode 313.000000. Reward 78.000000. action: 0.000000. mean reward 57.594036.
# World Perf: Episode 316.000000. Reward 63.000000. action: 1.000000. mean reward 59.509159.
# World Perf: Episode 319.000000. Reward 56.000000. action: 0.000000. mean reward 59.129810.
# World Perf: Episode 322.000000. Reward 51.333333. action: 1.000000. mean reward 59.348145.
# World Perf: Episode 325.000000. Reward 50.666667. action: 0.000000. mean reward 60.389896.
# World Perf: Episode 328.000000. Reward 81.666667. action: 1.000000. mean reward 60.113998.
# World Perf: Episode 331.000000. Reward 39.666667. action: 1.000000. mean reward 59.723293.
# World Perf: Episode 334.000000. Reward 37.333333. action: 0.000000. mean reward 59.258396.
# World Perf: Episode 337.000000. Reward 48.333333. action: 1.000000. mean reward 58.648392.
# World Perf: Episode 340.000000. Reward 45.333333. action: 1.000000. mean reward 58.024929.
# World Perf: Episode 343.000000. Reward 77.333333. action: 1.000000. mean reward 57.735836.
# World Perf: Episode 346.000000. Reward 51.666667. action: 1.000000. mean reward 61.684811.
# World Perf: Episode 349.000000. Reward 55.000000. action: 1.000000. mean reward 61.129192.
# World Perf: Episode 352.000000. Reward 66.666667. action: 0.000000. mean reward 60.725586.
# World Perf: Episode 355.000000. Reward 58.666667. action: 1.000000. mean reward 60.495495.
# World Perf: Episode 358.000000. Reward 84.666667. action: 1.000000. mean reward 60.372509.
# World Perf: Episode 361.000000. Reward 38.333333. action: 1.000000. mean reward 61.646832.
# World Perf: Episode 364.000000. Reward 54.666667. action: 1.000000. mean reward 64.454582.
# World Perf: Episode 367.000000. Reward 103.333333. action: 0.000000. mean reward 65.957558.
# World Perf: Episode 370.000000. Reward 87.333333. action: 1.000000. mean reward 65.945137.
# World Perf: Episode 373.000000. Reward 56.333333. action: 0.000000. mean reward 65.504608.
# World Perf: Episode 376.000000. Reward 66.333333. action: 1.000000. mean reward 70.206230.
# World Perf: Episode 379.000000. Reward 75.333333. action: 1.000000. mean reward 70.038567.
# World Perf: Episode 382.000000. Reward 38.000000. action: 0.000000. mean reward 69.184143.
# World Perf: Episode 385.000000. Reward 100.000000. action: 1.000000. mean reward 76.212662.
# World Perf: Episode 388.000000. Reward 124.000000. action: 1.000000. mean reward 77.480896.
# World Perf: Episode 391.000000. Reward 69.000000. action: 1.000000. mean reward 76.752945.
# World Perf: Episode 394.000000. Reward 88.333333. action: 1.000000. mean reward 76.361588.
# World Perf: Episode 397.000000. Reward 89.333333. action: 0.000000. mean reward 75.922829.
# World Perf: Episode 400.000000. Reward 57.666667. action: 0.000000. mean reward 75.840454.
# World Perf: Episode 403.000000. Reward 51.666667. action: 0.000000. mean reward 74.982391.
# World Perf: Episode 406.000000. Reward 91.000000. action: 0.000000. mean reward 74.494637.
# World Perf: Episode 409.000000. Reward 35.000000. action: 1.000000. mean reward 76.611443.
# World Perf: Episode 412.000000. Reward 35.333333. action: 0.000000. mean reward 75.555107.
# World Perf: Episode 415.000000. Reward 45.000000. action: 0.000000. mean reward 74.698143.
# World Perf: Episode 418.000000. Reward 87.666667. action: 1.000000. mean reward 80.339523.
# World Perf: Episode 421.000000. Reward 103.000000. action: 0.000000. mean reward 83.350296.
# World Perf: Episode 424.000000. Reward 69.666667. action: 0.000000. mean reward 85.418144.
# World Perf: Episode 427.000000. Reward 87.000000. action: 1.000000. mean reward 92.471382.
# World Perf: Episode 430.000000. Reward 97.666667. action: 1.000000. mean reward 100.388771.
# World Perf: Episode 433.000000. Reward 51.666667. action: 0.000000. mean reward 99.037193.
# World Perf: Episode 436.000000. Reward 79.000000. action: 1.000000. mean reward 97.995140.
# World Perf: Episode 439.000000. Reward 58.666667. action: 0.000000. mean reward 97.121071.
# World Perf: Episode 442.000000. Reward 113.333333. action: 1.000000. mean reward 97.045357.
# World Perf: Episode 445.000000. Reward 56.000000. action: 1.000000. mean reward 95.728539.
# World Perf: Episode 448.000000. Reward 68.333333. action: 0.000000. mean reward 94.627136.
# World Perf: Episode 451.000000. Reward 46.666667. action: 0.000000. mean reward 93.276062.
# World Perf: Episode 454.000000. Reward 58.333333. action: 0.000000. mean reward 92.804657.
# World Perf: Episode 457.000000. Reward 53.333333. action: 0.000000. mean reward 91.726982.
# World Perf: Episode 460.000000. Reward 135.333333. action: 0.000000. mean reward 92.154808.
# World Perf: Episode 463.000000. Reward 78.000000. action: 1.000000. mean reward 92.123993.
# World Perf: Episode 466.000000. Reward 107.666667. action: 0.000000. mean reward 93.596680.
# World Perf: Episode 469.000000. Reward 65.666667. action: 1.000000. mean reward 95.256523.
# World Perf: Episode 472.000000. Reward 91.000000. action: 0.000000. mean reward 97.150566.
# World Perf: Episode 475.000000. Reward 78.333333. action: 0.000000. mean reward 96.465096.
# World Perf: Episode 478.000000. Reward 91.666667. action: 0.000000. mean reward 98.012718.
# /Users/shawn/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:116: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)
# World Perf: Episode 481.000000. Reward 77.000000. action: 0.000000. mean reward 419968546551646650368.000000.
# World Perf: Episode 484.000000. Reward 122.333333. action: 0.000000. mean reward 411611167465014296576.000000.
# World Perf: Episode 487.000000. Reward 132.666667. action: 1.000000. mean reward 403420104905245851648.000000.
# World Perf: Episode 490.000000. Reward 105.333333. action: 1.000000. mean reward 395392086725737054208.000000.
# World Perf: Episode 493.000000. Reward 75.666667. action: 1.000000. mean reward 387523770411139465216.000000.
# World Perf: Episode 496.000000. Reward 73.333333. action: 1.000000. mean reward 379812059736709267456.000000.
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-10-ac0cc7865345> in <module>()
#      24         # Start displaying environment once performance is acceptably high.
#      25         if (reward_sum/batch_size > 150 and drawFromModel == False) or rendering == True :
# ---> 26             env.render()
#      27             rendering = True
#      28
#
# ~/anaconda3/lib/python3.6/site-packages/gym/core.py in render(self, mode)
#     282
#     283     def render(self, mode='human'):
# --> 284         return self.env.render(mode)
#     285
#     286     def close(self):
#
# ~/anaconda3/lib/python3.6/site-packages/gym/envs/classic_control/cartpole.py in render(self, mode)
#     105         if self.viewer is None:
#     106             from gym.envs.classic_control import rendering
# --> 107             self.viewer = rendering.Viewer(screen_width, screen_height)
#     108             l,r,t,b = -cartwidth/2, cartwidth/2, cartheight/2, -cartheight/2
#     109             axleoffset =cartheight/4.0
#
# ~/anaconda3/lib/python3.6/site-packages/gym/envs/classic_control/rendering.py in __init__(self, width, height, display)
#      49         self.width = width
#      50         self.height = height
# ---> 51         self.window = pyglet.window.Window(width=width, height=height, display=display)
#      52         self.window.on_close = self.window_closed_by_user
#      53         self.isopen = True
#
# ~/anaconda3/lib/python3.6/site-packages/pyglet/window/__init__.py in __init__(self, width, height, caption, resizable, style, fullscreen, visible, vsync, display, screen, config, context, mode)
#     502
#     503         if not screen:
# --> 504             screen = display.get_default_screen()
#     505
#     506         if not config:
#
# ~/anaconda3/lib/python3.6/site-packages/pyglet/canvas/base.py in get_default_screen(self)
#      71         :rtype: :class:`Screen`
#      72         '''
# ---> 73         return self.get_screens()[0]
#      74
#      75     def get_windows(self):
#
# ~/anaconda3/lib/python3.6/site-packages/pyglet/canvas/base.py in get_screens(self)
#      63         :rtype: list of :class:`Screen`
#      64         '''
# ---> 65         raise NotImplementedError('abstract')
#      66
#      67     def get_default_screen(self):
#
# NotImplementedError: abstract

# %%
plt.figure(figsize=(8, 12))
for i in range(6):
    plt.subplot(6, 2, 2*i + 1)
    plt.plot(pState[:,i])
    plt.subplot(6,2,2*i+1)
    plt.plot(state_nextsAll[:,i])
plt.tight_layout()
# Out:
# /Users/shawn/anaconda3/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:106: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
